# %%
import numpy as np
import wfdb

import matplotlib.pyplot as plt

# %%
# !pip install wfdb

# %%
record = wfdb.rdsamp('slp66')

record = np.asarray(record)

print(record.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-dc0fc416f790> in <module>
# ----> 1 record = wfdb.rdsamp('slp66')
#       2
#       3 record = np.asarray(record)
#       4
#       5 print(record.shape)
#
# ~\anaconda3\lib\site-packages\wfdb\io\record.py in rdsamp(record_name, sampfrom, sampto, channels, pn_dir, channel_names, warn_empty, return_res)
#    3688         pn_dir = posixpath.join(dir_list[0], get_version(dir_list[0]), *dir_list[1:])
#    3689
# -> 3690     record = rdrecord(record_name=record_name, sampfrom=sampfrom,
#    3691                       sampto=sampto, channels=channels, physical=True,
#    3692                       pn_dir=pn_dir, m2s=True, return_res=return_res,
#
# ...

# %%
data = np.fromfile('./slp66.dat', dtype="byte")
print(data.shape)
# Out:
# (34650000,)

# %%
data2 = data[:100]

# %%
plt.figure()
plt.plot(np.linspace(0, len(data2), len(data2)), data2)
plt.show()

# %%
ecg_data = np.fromfile('./slp66.ecg')

# %%
ecg_data2 = ecg_data[:100]

# %%
plt.figure()
plt.plot(np.linspace(0, len(ecg_data2), len(ecg_data2)), ecg_data2)
plt.show()
